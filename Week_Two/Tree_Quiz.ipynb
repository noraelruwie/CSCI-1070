# %%
months = ["January","February","March","April","May","June","July","August","September","October","November","December"]
month = ["March"]
index = months.index("March") 
print(index)
# Out:
# 2

# %%
birthday = months[index]
print(birthday)
# Out:
# March

# %%
print(birthday + " is my birthday")
# Out:
# March is my birthday

# %% [markdown]
# ![Screenshot 2024-01-24 at 7.26.35 PM.png](attachment:2d22515c-6ccf-4f97-9432-c5149b4c2086.png)

# %%
#Question 2 - The entirety of this tree is what is inside of my repo. The two untitled documents are notebooks that I was practicing on. 
# Week Two is a folder I attempted to make but had forgotten to add an underscore. Week_Two is the folder where I keep my notebooks for this week of class. 
#1-24-2024 is the notebook I used for the warmup of this class. 
#Loops and Functions 1 & 2 are notebooks from today’s class, the first notebook crashed. Data Terminals is from Monday’s Zoom class.
